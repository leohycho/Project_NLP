# %%
from gensim.models import Word2Vec

model = Word2Vec.load('nvmc.model')
print("corpus_total_words : ", model.corpus_total_words)
# Out:
# corpus_total_words :  1076896

# %%
print('사랑 : ', model.wv['사랑'])
# Out:
# 사랑 :  [-0.0413832  -0.34985614  0.38640684  0.10737752  0.07500341 -0.3431507
#  -0.20323995  0.21194002  0.3000332   0.15832958 -0.09818678  0.02698207
#   0.14321776 -0.05724344 -0.03511371  0.02819706 -0.18996039 -0.00155084
#  -0.20230539 -0.18548883 -0.08022047  0.09212465 -0.266758    0.33375245
#  -0.07455581  0.04068844  0.05608967 -0.11536217  0.13603157 -0.04810518
#   0.25920025 -0.0402675   0.0630221   0.13013639  0.18743737  0.33577397
#   0.25991124 -0.15227948  0.14171831 -0.14171398 -0.32620257  0.05433082
#  -0.01402342 -0.12371325  0.27696908  0.03226476 -0.19229437 -0.27590853
#   0.41368756  0.1605102  -0.02923208 -0.1939765  -0.10178207  0.00203827
#   0.08375183  0.06026165  0.3996826  -0.15038401  0.10940589 -0.10170276
#   0.12688133 -0.30473465 -0.04188589 -0.12649213 -0.09514111  0.03394593
#  -0.30614164  0.02841758  0.04212101  0.43356806 -0.02044149 -0.15890257
#   0.20911345  0.01119279 -0.02628195  0.14045168  0.28275424 -0.1212322
#  -0.26578775  0.16504969 -0.12834804 -0.15720098  0.03472276  0.35861197
#  -0.2023135  -0.24399765  0.01595962  0.25224435 -0.06138467  0.3077671
#   0.26491153  0.547208    0.06986172 -0.10965739  0.4343591  -0.20992172
#  -0.18732709 -0.24141748 -0.1668843  -0.17585783 -0.3452532   0.5015907
#   0.13277288 -0.15247832  0.1006372  -0.13967974  0.09249385  0.01416454
#  -0.0556834  -0.38515708  0.00962406 -0.4428654  -0.03339411 -0.06044129
#   0.19717792 -0.2779066   0.15066278 -0.05490591  0.1207243  -0.09075536
#  -0.0068051   0.09876481 -0.08035423 -0.07827336 -0.18117076  0.44567186
#  -0.18111347  0.02747743 -0.2138167  -0.05231433 -0.05031921  0.48721305
#  -0.10285132  0.08960443  0.13805681  0.11577113  0.32032454 -0.49338278
#  -0.05574955  0.15456451  0.10872298 -0.2671786  -0.17199767 -0.10990793
#   0.08110885 -0.08359761 -0.24762239 -0.21966062 -0.20575924  0.05346172
#  -0.15187147 -0.1329153   0.24331169 -0.11952643 -0.11099247  0.03507962
#   0.54810035  0.16979858  0.15555154 -0.18066885  0.20865096 -0.2731759
#   0.09677864  0.04347735 -0.10194886  0.15491784 -0.13623491 -0.15328772
#   0.06478772 -0.04452704 -0.49513233  0.22035684  0.383913   -0.48877248
#  -0.07338179  0.08587734  0.22279672 -0.27031592  0.0595791  -0.02683557
#  -0.10887405  0.10544235 -0.0616005   0.01897773 -0.13810255 -0.12282225
#  -0.13387537 -0.06852093  0.12175544 -0.08735979  0.25314128 -0.13152787
#   0.05729511 -0.12169894  0.15698819 -0.16616671 -0.04787686 -0.2473382
#  -0.09394083  0.11806693]

# %%
print('일요일 = 월요일\t', model.wv.similarity(w1='일요일', w2='월요일'))
print('안성기 = 배우\t', model.wv.similarity(w1='안성기', w2='배우'))
print('대기업 = 삼성\t', model.wv.similarity(w1='대기업', w2='삼성'))
print('일요일 != 삼성\t', model.wv.similarity(w1='일요일', w2='삼성'))
print('히어로 != 삼성\t', model.wv.similarity(w1='히어로', w2='삼성'))
# Out:
# 일요일 = 월요일	 0.64811337
# 안성기 = 배우	 0.5754178
# 대기업 = 삼성	 0.49889064
# 일요일 != 삼성	 0.2302195
# 히어로 != 삼성	 0.17913891

# %%
print(model.wv.most_similar('안성기', topn=5))
print(model.wv.most_similar('시리즈', topn=5))
# Out:
# [('김갑수', 0.7141665816307068), ('문소리', 0.7125629186630249), ('정려원', 0.7075937390327454), ('씨야', 0.7072511315345764), ('장미희', 0.7033379077911377)]
# [('X맨', 0.6529797911643982), ('캐리비안의 해적', 0.6461828947067261), ('나니아 연대기', 0.6430087089538574), ('비포 선셋', 0.6318771243095398), ('나이트메어', 0.6266482472419739)]
